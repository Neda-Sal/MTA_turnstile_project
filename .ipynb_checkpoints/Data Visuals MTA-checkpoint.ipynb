# %%
import pandas as pd
import datetime

# %%
#load the data back in use
stations_daily_top25 = pd.read_pickle('stations_daily_top25.pkl')
stations_w_income = pd.read_pickle('top_25_with_income.pkl')
stations_charitable_donors = pd.read_pickle('top_25_with_charitable_donations.pkl')

# %%
stations_daily_top25.head()
# Out:
#       C/A  UNIT STATION LINENAME        DATE    ENTRIES      EXITS  \
# 106  A013  R081   49 ST     NQRW  08/30/2020  152575761  307855750
# 107  A013  R081   49 ST     NQRW  08/31/2020  152578932  307861117
# 108  A013  R081   49 ST     NQRW  09/01/2020  152584490  307867719
# 109  A013  R081   49 ST     NQRW  09/02/2020  152590227  307874563
# 112  A013  R081   49 ST     NQRW  09/05/2020  152607649  307894332
#
#     Previous_date  Previous_Entries  Daily_Entries STATION_LINE
# 106    08/29/2020       152572931.0         2830.0   49 ST NQRW
# 107    08/30/2020       152575761.0         3171.0   49 ST NQRW
# 108    08/31/2020       152578932.0         5558.0   49 ST NQRW
# 109    09/01/2020       152584490.0         5737.0   49 ST NQRW
# 112    09/04/2020       152602116.0         5533.0   49 ST NQRW

# %%
stations_w_income.head()
# Out:
#          STATION_LINE  Daily_Entries_x         STATION  LINENAME  zipcode  \
# 0  34 ST-PENN STA ACE           387800  34 ST-PENN STA       ACE    10001
# 1           28 ST NRW           219660           28 ST       NRW    10001
# 2  FULTON ST 2345ACJZ           376692       FULTON ST  2345ACJZ    10038
# 3          WALL ST 23           269157         WALL ST        23    10038
# 4        14 ST FLM123           338837           14 ST    FLM123    10019
#
#    zip_code  number_of_returns
# 0     10001               6370
# 1     10001               6370
# 2     10038               4780
# 3     10038               4780
# 4     10019              12120

# %%
stations_w_income = stations_w_income.drop(columns = 'zipcode')

# %%
stations_w_income = stations_w_income.rename(columns = {'Daily_Entries_x': 'Daily_Entries'})

# %%
stations_w_income.head()
# Out:
#          STATION_LINE  Daily_Entries         STATION  LINENAME  zip_code  \
# 0  34 ST-PENN STA ACE         387800  34 ST-PENN STA       ACE     10001
# 1           28 ST NRW         219660           28 ST       NRW     10001
# 2  FULTON ST 2345ACJZ         376692       FULTON ST  2345ACJZ     10038
# 3          WALL ST 23         269157         WALL ST        23     10038
# 4        14 ST FLM123         338837           14 ST    FLM123     10019
#
#    number_of_returns
# 0               6370
# 1               6370
# 2               4780
# 3               4780
# 4              12120

# %% [markdown]
# ## Some vis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
stations_daily_top25.head()
# Out:
#       C/A  UNIT STATION LINENAME        DATE    ENTRIES      EXITS  \
# 106  A013  R081   49 ST     NQRW  08/30/2020  152575761  307855750
# 107  A013  R081   49 ST     NQRW  08/31/2020  152578932  307861117
# 108  A013  R081   49 ST     NQRW  09/01/2020  152584490  307867719
# 109  A013  R081   49 ST     NQRW  09/02/2020  152590227  307874563
# 112  A013  R081   49 ST     NQRW  09/05/2020  152607649  307894332
#
#     Previous_date  Previous_Entries  Daily_Entries STATION_LINE
# 106    08/29/2020       152572931.0         2830.0   49 ST NQRW
# 107    08/30/2020       152575761.0         3171.0   49 ST NQRW
# 108    08/31/2020       152578932.0         5558.0   49 ST NQRW
# 109    09/01/2020       152584490.0         5737.0   49 ST NQRW
# 112    09/04/2020       152602116.0         5533.0   49 ST NQRW

# %%
plt.figure(figsize = (6, 10))
sns.boxplot('Daily_Entries', 'STATION_LINE', data=stations_daily_top25)

# %% [markdown]
# ## Split by weekend and weekday traffic

# %%
stations_daily_top25_copy = stations_daily_top25.copy()

# %%
#make a new column thats a date time object to put day of the week
stations_daily_top25_copy['Dateobject'] = pd.to_datetime(stations_daily_top25_copy['DATE'], format='%m/%d/%Y')

# %%
stations_daily_top25_copy['Day_of_Week'] = stations_daily_top25_copy['Dateobject'].dt.dayofweek

# %%
stations_daily_top25_copy.head()
# Out:
#       C/A  UNIT STATION LINENAME        DATE    ENTRIES      EXITS  \
# 106  A013  R081   49 ST     NQRW  08/30/2020  152575761  307855750
# 107  A013  R081   49 ST     NQRW  08/31/2020  152578932  307861117
# 108  A013  R081   49 ST     NQRW  09/01/2020  152584490  307867719
# 109  A013  R081   49 ST     NQRW  09/02/2020  152590227  307874563
# 112  A013  R081   49 ST     NQRW  09/05/2020  152607649  307894332
#
#     Previous_date  Previous_Entries  Daily_Entries STATION_LINE Dateobject  \
# 106    08/29/2020       152572931.0         2830.0   49 ST NQRW 2020-08-30
# 107    08/30/2020       152575761.0         3171.0   49 ST NQRW 2020-08-31
# 108    08/31/2020       152578932.0         5558.0   49 ST NQRW 2020-09-01
# 109    09/01/2020       152584490.0         5737.0   49 ST NQRW 2020-09-02
# 112    09/04/2020       152602116.0         5533.0   49 ST NQRW 2020-09-05
#
#      Day_of_Week
# 106            6
# 107            0
# 108            1
# 109            2
# 112            5

# %% [markdown]
# Filter the data with weekday and weekend masks

# %%
weekdays_mask = (stations_daily_top25_copy['Day_of_Week'].isin([0,1,2,3,4]))

# %%
weekday_df = stations_daily_top25_copy[weekdays_mask]

# %%
weekend_mask = (stations_daily_top25_copy['Day_of_Week'].isin([5,6]))

# %%
weekend_df = stations_daily_top25_copy[weekend_mask]

# %%
weekday_graph_data = weekday_df.groupby('STATION_LINE')[['Daily_Entries']].sum().sort_values(['Daily_Entries'], ascending = True)
weekend_graph_data = weekend_df.groupby('STATION_LINE')[['Daily_Entries']].sum().sort_values(['Daily_Entries'], ascending = True)

# %%
weekday_graph_data
# Out:
#                     Daily_Entries
# STATION_LINE
# ROCKAWAY BLVD A          161678.0
# BEDFORD-NOSTRAN G        162777.0
# 86 ST 1                  166997.0
# 28 ST NRW                167633.0
# 181 ST A                 172782.0
# CATHEDRAL PKWY BC        173222.0
# MYRTLE-WILLOUGH G        174390.0
# 66 ST-LINCOLN 1          176245.0
# 174-175 STS BD           177984.0
# FT HAMILTON PKY N        179421.0
# HOUSTON ST 1             184200.0
# 170 ST BD                184780.0
# 125 ST 23                189771.0
# VERNON-JACKSON 7         201559.0
# WALL ST 23               206982.0
# 51 ST 6                  208506.0
# 46 ST MR                 213555.0
# 23 ST 6                  217632.0
# CORTLANDT ST RNW         219898.0
# 49 ST NQRW               224085.0
# KINGSBRIDGE RD BD        229611.0
# 33 ST 6                  256150.0
# 14 ST FLM123             268260.0
# FULTON ST 2345ACJZ       287861.0
# 34 ST-PENN STA ACE       303758.0

# %%
weekdayx = list(weekday_graph_data.index)
weekdayy = list(weekday_graph_data['Daily_Entries'])
weekendx = list(weekend_graph_data.index)
weekendy = list(weekend_graph_data['Daily_Entries'])

# %%
plt.figure(figsize=(4,10))
plt.xlabel('Total Entries (per 4wks)')
plt.title('Weekday Turnstile Entries', fontsize = 15, weight = 'bold')
plt.barh(weekdayx,weekdayy)
plt.savefig('weekday_plot.png', dpi=300, bbox_inches='tight');

# %%
plt.figure(figsize=(4,10))
plt.xlabel('Total Entries (per 4wks)')
plt.title('Weekend Turnstile Entries', fontsize = 15, weight = 'bold')
plt.barh(weekendx,weekendy)
plt.savefig('weekend_plot.png', dpi=300, bbox_inches='tight');

# %% [markdown]
# ## look at the stations that have highest income by zip code

# %%
stations_w_income.head()
# Out:
#          STATION_LINE  Daily_Entries         STATION  LINENAME  zip_code  \
# 0  34 ST-PENN STA ACE         387800  34 ST-PENN STA       ACE     10001
# 1           28 ST NRW         219660           28 ST       NRW     10001
# 2  FULTON ST 2345ACJZ         376692       FULTON ST  2345ACJZ     10038
# 3          WALL ST 23         269157         WALL ST        23     10038
# 4        14 ST FLM123         338837           14 ST    FLM123     10019
#
#    number_of_returns
# 0               6370
# 1               6370
# 2               4780
# 3               4780
# 4              12120

# %%
income_graph_data = stations_w_income.groupby('STATION_LINE')[['number_of_returns']].sum().sort_values(['number_of_returns'], ascending = True)

# %%
income_graph_data
# Out:
#                     number_of_returns
# STATION_LINE
# 174-175 STS BD                    750
# 170 ST BD                         780
# KINGSBRIDGE RD BD                1230
# 33 ST 6                          1280
# 51 ST 6                          1280
# ROCKAWAY BLVD A                  1440
# 66 ST-LINCOLN 1                  2140
# 181 ST A                         2220
# CORTLANDT ST RNW                 2420
# 46 ST MR                         3140
# CATHEDRAL PKWY BC                3380
# BEDFORD-NOSTRAN G                3410
# FT HAMILTON PKY N                3750
# MYRTLE-WILLOUGH G                4170
# 125 ST 23                        4490
# FULTON ST 2345ACJZ               4780
# WALL ST 23                       4780
# 34 ST-PENN STA ACE               6370
# 28 ST NRW                        6370
# VERNON-JACKSON 7                 7330
# 23 ST 6                          8580
# HOUSTON ST 1                    10270
# 49 ST NQRW                      12120
# 14 ST FLM123                    12120
# 86 ST 1                         15740

# %%
incomex = list(income_graph_data.index)
incomey = list(income_graph_data['number_of_returns'])

# %%
plt.figure(figsize=(4,10))
plt.xlabel('Number Tax Returns Reporting $100k+')
plt.title('Highest Income Areas', fontsize = 15, weight = 'bold')
plt.barh(incomex,incomey)
plt.savefig('high_income_plot.png', dpi=300, bbox_inches='tight');


#plt.plot( , )

# %% [markdown]
# ### Consider high charitable contribution areas

# %%
stations_charitable_donors.head()
# Out:
#          STATION_LINE  Daily_Entries_x         STATION  LINENAME  zipcode  \
# 0  34 ST-PENN STA ACE           387800  34 ST-PENN STA       ACE    10001
# 1           28 ST NRW           219660           28 ST       NRW    10001
# 2  FULTON ST 2345ACJZ           376692       FULTON ST  2345ACJZ    10038
# 3          WALL ST 23           269157         WALL ST        23    10038
# 4        14 ST FLM123           338837           14 ST    FLM123    10019
#
#    zip_code  number_of_returns_charitable_contribution
# 0     10001                                       1770
# 1     10001                                       1770
# 2     10038                                       1320
# 3     10038                                       1320
# 4     10019                                       3760

# %%
#clean up the df a bit
stations_charitable_donors = stations_charitable_donors.drop(columns = 'zipcode')
stations_charitable_donors = stations_charitable_donors.rename(columns = {'Daily_Entries_x': 'Daily_Entries'})

# %%
stations_charitable_donors.head()
# Out:
#          STATION_LINE  Daily_Entries         STATION  LINENAME  zip_code  \
# 0  34 ST-PENN STA ACE         387800  34 ST-PENN STA       ACE     10001
# 1           28 ST NRW         219660           28 ST       NRW     10001
# 2  FULTON ST 2345ACJZ         376692       FULTON ST  2345ACJZ     10038
# 3          WALL ST 23         269157         WALL ST        23     10038
# 4        14 ST FLM123         338837           14 ST    FLM123     10019
#
#    number_of_returns_charitable_contribution
# 0                                       1770
# 1                                       1770
# 2                                       1320
# 3                                       1320
# 4                                       3760

# %%
stations_charitable_donors = stations_charitable_donors.groupby('STATION_LINE')[['number_of_returns_charitable_contribution']].sum().sort_values(['number_of_returns_charitable_contribution'], ascending = True)

# %%
donorx = list(stations_charitable_donors.index)
donory = list(stations_charitable_donors['number_of_returns_charitable_contribution'])

# %%
plt.figure(figsize=(4,10))
plt.xlabel('Number of Tax Reports Reporting Charitable Donations')
plt.title('Concentration of Charitable Donors', fontsize = 15, weight = 'bold')
plt.barh(donorx,donory)
plt.savefig('charity.png', dpi=300, bbox_inches='tight');


#plt.plot( , )

# %% [markdown]
# ## FINAL SUGGESETIONS
#
# **Weekend:**
#
# *(priority)*
#
# 86 ST 1
#
# 34 ST PENN - STA ACE
#
# 14 ST FLM123
#
# 49 ST NQRW
#
# VERNON JACKSON 7
#
# WALL ST 23
#
# FULTON ST 2345ACJZ
#
# 125 ST 23
#
# 28 ST NRW
#
# *(if have more resources)*
#
# HOUSTON ST 1
#
# 23 ST 6
#
# ___
#
# **Weekday:**
#
# *(priority)*
#
# 34 ST PENN - STA ACE
#
# 14 ST FLM123
#
# 49 ST NQRW
#
# 23 ST 6
#
# FULTON ST 2345ACJZ
#
# WALL ST 23
#
# VERNON JACKSON 7
#
# 125 ST 23
#
# HOUSTON ST 1
#
# *(if have more resources)*
#
# 86 ST 1
#
# 28 ST NRW

# %% [markdown]
# Just some extra visuals

# %%
#just want the top 11 now
final_mask = ((stations_w_income['STATION_LINE'] == "34 ST PENN - STA ACE") | 
(stations_w_income['STATION_LINE'] == "14 ST FLM123") | 
((stations_w_income['STATION_LINE'] == "49 ST NQRW") |
(stations_w_income['STATION_LINE'] == "23 ST 6")) | 
(stations_w_income['STATION_LINE'] == "FULTON ST 2345ACJZ") |
(stations_w_income['STATION_LINE'] == "WALL ST 23") |
(stations_w_income['STATION_LINE'] == "VERNON JACKSON 7") |
(stations_w_income['STATION_LINE'] == "125 ST 23") |
(stations_w_income['STATION_LINE'] == "HOUSTON ST 1") |
(stations_w_income['STATION_LINE'] == "86 ST 1") |
(stations_w_income['STATION_LINE'] == "28 ST NRW"))

# %%
final_11_stations = stations_w_income[final_mask]

# %%
final_11_stations
# Out:
#           STATION_LINE  Daily_Entries     STATION  LINENAME  zip_code  \
# 1            28 ST NRW         219660       28 ST       NRW     10001
# 2   FULTON ST 2345ACJZ         376692   FULTON ST  2345ACJZ     10038
# 3           WALL ST 23         269157     WALL ST        23     10038
# 4         14 ST FLM123         338837       14 ST    FLM123     10019
# 5           49 ST NQRW         293311       49 ST      NQRW     10019
# 12             23 ST 6         256849       23 ST         6     10010
# 13           125 ST 23         247659      125 ST        23     10027
# 14             86 ST 1         242629       86 ST         1     10024
# 18        HOUSTON ST 1         227680  HOUSTON ST         1     10014
#
#     number_of_returns
# 1                6370
# 2                4780
# 3                4780
# 4               12120
# 5               12120
# 12               8580
# 13               4490
# 14              15740
# 18              10270

# %%
weekday_graph_data.index[final_mask]
# Out:
# Index(['BEDFORD-NOSTRAN G', '86 ST 1', '28 ST NRW', '181 ST A',
#        'CATHEDRAL PKWY BC', '125 ST 23', 'VERNON-JACKSON 7', 'WALL ST 23',
#        'CORTLANDT ST RNW'],
#       dtype='object', name='STATION_LINE')

# %%
weekday11x = list(final_11_stations['STATION_LINE'])
weekday11y = list(final_11_stations['Daily_Entries'])
weekend11x = list(final_11_stations['STATION_LINE'])
weekend11y = list(final_11_stations['Daily_Entries'])

# %%
#plt.figure(figsize=(3,))
plt.xlabel('Total Entries (per 4wks)')
plt.title('Weekday Turnstile Entries')
plt.barh(weekday11x,weekday11y)
plt.savefig('weekday_plot.png', dpi=300, bbox_inches='tight');
# Out:
# <BarContainer object of 9 artists>
